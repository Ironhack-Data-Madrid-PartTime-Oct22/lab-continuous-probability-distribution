# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pylab as p
from scipy.stats import norm
from scipy.stats import uniform
from scipy.stats import expon

# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.79953634 2.49421567 2.30804507 2.57093227 2.08377945 2.75766543
#  2.56580687 2.35153504 2.598329   2.68213728]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
import random

def generate_uniform(bottom, ceiling, count):
    return [random.uniform(bottom, ceiling) for _ in range(count)]

# %%
numbers1 = generate_uniform(bottom=10, ceiling=15, count=100)

plt.hist(numbers1, bins=10)
plt.title('Uniform Distribution (bottom=10, ceiling=15, count=100)')
plt.show()


numbers2 = generate_uniform(bottom=10, ceiling=60, count=1000)

plt.hist(numbers2, bins=10)
plt.title('Uniform Distribution (bottom=10, ceiling=60, count=1000)')
plt.show()

# %%
#function1= np.linspace(10, 15, 100)
#function2= np.linspace(10, 60, 1000)

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The two distributions are different due to their different ranges and sample sizes, which can affect their shape and variability. The first distribution is likely to be more clustered together, while the second distribution is more spread out and uniform.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here
def generate_normal(mean, std_dev, count):
    return [random.normalvariate(mean, std_dev) for _ in range(count)]

# %%
normal1 = generate_normal(mean=10, std_dev=1, count=1000)

plt.hist(normal1, bins=50)
plt.title('Normal Distribution (mean=10, std_dev=1)')
plt.show()


normal2 = generate_normal(mean=10, std_dev=50, count=1000)

plt.hist(normal2, bins=50)
plt.title('Normal Distribution (mean=10, std_dev=50)')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The two distributions are different due to their different standard deviation values, which determine the spread of the data points around the mean value. The first distribution is more peaked and less spread out, while the second distribution is flatter and more spread out, with a larger number of values far from the mean.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:

# %%
# your code here
dfvehicles = pd.read_csv("vehicles.csv", sep=',', encoding='UTF-8',index_col=0)
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
dfvehicles.head(1)
# Out:
#                         Model  Year  Engine Displacement  Cylinders  \
# Make
# AM General  DJ Po Vehicle 2WD  1984                  2.5        4.0
#
#                Transmission     Drivetrain                Vehicle Class  \
# Make
# AM General  Automatic 3-spd  2-Wheel Drive  Special Purpose Vehicle 2WD
#
#            Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# Make
# AM General   Regular          19.388824        18           17            17
#
#             CO2 Emission Grams/Mile  Fuel Cost/Year
# Make
# AM General               522.764706            1950

# %% [markdown]
# 1. Fuel Barrels/Year

# %%
plt.hist(dfvehicles['Fuel Barrels/Year'], bins=50)
plt.title('Fuel Barrels/Year Distribution')
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
plt.hist(dfvehicles['CO2 Emission Grams/Mile'], bins=50)
plt.title('CO2 Emission Grams/Mile Distribution')
plt.xlabel('CO2 Emission Grams/Mile')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
plt.hist(dfvehicles['Combined MPG'], bins=50)
plt.title('Combined MPG Distribution')
plt.xlabel('Combined MPG')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %% [markdown]
# By visually inspecting the histograms, we can identify which variable(s) are nearly normally distributed. A nearly normally distributed variable will have a bell-shaped curve that is roughly symmetrical around the mean value

# %% [markdown]
# Combined MPG variable has distribution that is approximately normally distributed. The histograms shows a roughly bell-shaped curve that is symmetrical around the mean value. However, is not a perfect normal distribution, as there are some deviations from a perfect bell shape in the histogram.

# %% [markdown]
# Other variables, such as CO2 Emission Grams/Mile and Fuel Barrels/Year, do not have a normal distribution. Their histograms show skewed distributions that are not symmetrical around the mean value.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
def exponential(mean, size):
    return np.random.exponential(scale=mean, size=size)

# %%
expo1 = exponential(10, 10)
expo2 = exponential(10, 100)

# %%
plt.hist(expo1, bins=100)
plt.title('Exponential Distribution (size=10)')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

plt.hist(expo2, bins=100)
plt.title('Exponential Distribution (size=100)')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The larger the sample size, the closer the distribution will resemble the underlying probability distribution. Therefore, the second distribution should be a better approximation of the true exponential distribution with a mean of 10 compared to the first distribution.

# %% [markdown]
# The first distribution has only 10 samples, the histogram is more susceptible to random variation and does not display the typical bell shape of the exponential distribution. The second distribution, on the other hand, has a larger sample size of 100, which allows the histogram to more accurately represent the exponential distribution with a bell shape centered around the mean value of 10.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
import math
mu = 10
lambda_ = 1/mu
t = 15

p = 1 - math.exp(-lambda_ * t)
p
# Out:
# 0.7768698398515702

# %%
my_e = expon(scale=10)
my_e.cdf(15)
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
my_exp2 = 1- my_e.cdf(15)
my_exp2
# Out:
# 0.2231301601484298
